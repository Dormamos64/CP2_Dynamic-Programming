# %% [markdown]
# Grupo
#
# Felipe Yamaguchi Mesquita RM 556170
# Rafael Tavares Santos RM: 563487
# Gabriel oliveira amaral RM: 563872

# %% [markdown]
# Grafos e Logica

# %%
import functools
import time
import tracemalloc
import folium

grafos = {
    "Beijing": {
        "Sihui East": [("Sihui", 2)],
        "Sihui": [("Sihui East", 2), ("Dawanglu", 3)],
        "Dawanglu": [("Sihui", 3), ("Guomao", 2)],
        "Guomao": [("Dawanglu", 2), ("Jianguomen", 4), ("Hujialou", 3)],
        "Hujialou": [("Guomao", 3), ("Tuanjiehu", 2)],
        "Tuanjiehu": [("Hujialou", 2), ("Sanyuanqiao", 5)],
        "Sanyuanqiao": [("Tuanjiehu", 5), ("Shaoyaoju", 4)],
        "Shaoyaoju": [("Sanyuanqiao", 4), ("Zhichunlu", 8)],
        "Zhichunlu": [("Shaoyaoju", 8), ("Xizhimen", 5)],
        "Jianguomen": [("Guomao", 4), ("Dongdan", 2), ("Chaoyangmen", 3)],
        "Dongdan": [("Jianguomen", 2), ("Wangfujing", 2)],
        "Wangfujing": [("Dongdan", 2), ("Tiananmen East", 2)],
        "Tiananmen East": [("Wangfujing", 2), ("Xidan", 4)],
        "Xidan": [("Tiananmen East", 4), ("Fuxingmen", 3), ("Xuanwumen", 2)],
        "Xuanwumen": [("Xidan", 2), ("Hepingmen", 2)],
        "Hepingmen": [("Xuanwumen", 2), ("Qianmen", 2)],
        "Chaoyangmen": [("Jianguomen", 3), ("Dongsi", 3)],
        "Fuxingmen": [("Xidan", 3), ("Fuchengmen", 3)],
        "Fuchengmen": [("Fuxingmen", 3), ("Chegongzhuang", 2)],
        "Chegongzhuang": [("Fuchengmen", 2), ("Xizhimen", 2)],
        "Xizhimen": [("Chegongzhuang", 2), ("Zhichunlu", 5)]
    },
    "San Francisco": {
        "Dublin/Pleasanton": [("West Dublin", 3)],
        "West Dublin": [("Dublin/Pleasanton", 3), ("Castro Valley", 10)],
        "Castro Valley": [("West Dublin", 10), ("Bay Fair", 8)],
        "Bay Fair": [("Castro Valley", 8), ("San Leandro", 5), ("Hayward", 6)],
        "San Leandro": [("Bay Fair", 5), ("Coliseum", 6)],
        "Coliseum": [("San Leandro", 6), ("Fruitvale", 5)],
        "Fruitvale": [("Coliseum", 5), ("Lake Merritt", 6)],
        "Lake Merritt": [("Fruitvale", 6), ("West Oakland", 5)],
        "West Oakland": [("Lake Merritt", 5), ("Embarcadero", 10), ("12th St Oakland", 4)],
        "12th St Oakland": [("West Oakland", 4), ("19th St Oakland", 2)],
        "19th St Oakland": [("12th St Oakland", 2), ("MacArthur", 3)],
        "MacArthur": [("19th St Oakland", 3), ("Rockridge", 5)],
        "Embarcadero": [("West Oakland", 10), ("Montgomery St", 2)],
        "Montgomery St": [("Embarcadero", 2), ("Powell St", 2)],
        "Powell St": [("Montgomery St", 2), ("Civic Center", 2)],
        "Civic Center": [("Powell St", 2), ("16th St Mission", 3)],
        "16th St Mission": [("Civic Center", 3), ("24th St Mission", 2)],
        "24th St Mission": [("16th St Mission", 2), ("Glen Park", 4)],
        "Glen Park": [("24th St Mission", 4), ("Balboa Park", 3)],
        "Balboa Park": [("Glen Park", 3), ("Daly City", 3)],
        "Daly City": [("Balboa Park", 3)]
    },
    "Sao Paulo": { 
        "Tucuruvi": [("Parada Inglesa", 3)],
        "Parada Inglesa": [("Tucuruvi", 3), ("Jardim Sao Paulo", 2)],
        "Jardim Sao Paulo": [("Parada Inglesa", 2), ("Santana", 3)],
        "Santana": [("Jardim Sao Paulo", 3), ("Carandiru", 2)],
        "Carandiru": [("Santana", 2), ("Portuguesa-Tiete", 2)],
        "Portuguesa-Tiete": [("Carandiru", 2), ("Armenia", 3)],
        "Armenia": [("Portuguesa-Tiete", 3), ("Luz", 4)],
        "Luz": [("Armenia", 4), ("Sao Bento", 2), ("Republica", 5)],
        "Sao Bento": [("Luz", 2), ("Se", 2)],
        "Se": [("Sao Bento", 2), ("Liberdade", 2)],
        "Liberdade": [("Se", 2), ("Paraiso", 4)],
        "Paraiso": [("Liberdade", 4), ("Ana Rosa", 2)],
        "Ana Rosa": [("Paraiso", 2), ("Vila Mariana", 3)],
        "Vila Mariana": [("Ana Rosa", 3), ("Santa Cruz", 3)],
        "Santa Cruz": [("Vila Mariana", 3), ("Hospital Sao Paulo", 3)],
        "Republica": [("Luz", 5), ("Santa Cruz", 15)],
        "Hospital Sao Paulo": [("Santa Cruz", 3), ("AACD-Servidor", 3)],
        "AACD-Servidor": [("Hospital Sao Paulo", 3), ("Moema", 3)],
        "Moema": [("AACD-Servidor", 3), ("Eucaliptos", 3)],
        "Eucaliptos": [("Moema", 3), ("Campo Belo", 4)],
        "Campo Belo": [("Eucaliptos", 4), ("Brooklin", 3)],
        "Brooklin": [("Campo Belo", 3), ("Santo Amaro", 5)],
        "Santo Amaro": [("Brooklin", 5), ("Giovanni Gronchi", 3)],
        "Giovanni Gronchi": [("Santo Amaro", 3), ("Vila das Belezas", 2)],
        "Vila das Belezas": [("Giovanni Gronchi", 2), ("Capao Redondo", 4)],
        "Capao Redondo": [("Vila das Belezas", 4)]
    }
}

coords = {
    "Beijing": {
        "Sihui East": [39.908, 116.514], "Xizhimen": [39.940, 116.355],
        "Guomao": [39.908, 116.460], "Jianguomen": [39.908, 116.435]
    },
    "San Francisco": {
        "Dublin/Pleasanton": [37.701, -121.899], "Daly City": [37.706, -122.469],
        "West Oakland": [37.804, -122.295], "Embarcadero": [37.792, -122.397]
    },
    "Sao Paulo": {
        "Tucuruvi": [-23.480, -46.603], "Capao Redondo": [-23.659, -46.768],
        "Luz": [-23.536, -46.634], "Santa Cruz": [-23.598, -46.636]
    }
}

def get_fator(horario):
    if 5 <= horario < 7: return 0.6
    if 7 <= horario < 9: return 1.5
    if 17 <= horario <= 20: return 2.0
    return 1.0

def resolver_cidade(nome_cidade, origem, destino, horario):
    grafo = grafos[nome_cidade]
    fator = get_fator(horario)

    @functools.lru_cache(maxsize=None)
    def menor_custo(u, v, visitados=frozenset()):
        if u == v: return 0, (v,)
        melhor_c = float('inf')
        melhor_p = ()
        for vizinho, peso in grafo.get(u, []):
            if vizinho not in visitados:
                c, p = menor_custo(vizinho, v, visitados | {u})
                custo_total = (peso * fator) + c
                if custo_total < melhor_c:
                    melhor_c, melhor_p = custo_total, (u,) + p
        return melhor_c, melhor_p

    def maior_custo(u, v, visitados=None):
        if visitados is None: visitados = set()
        if u == v: return 0, (v,)
        visitados.add(u)
        pior_c, pior_p = -1, ()
        for vizinho, peso in grafo.get(u, []):
            if vizinho not in visitados:
                c, p = maior_custo(vizinho, v, visitados)
                if c != -1:
                    custo_total = (peso * fator) + c
                    if custo_total > pior_c:
                        pior_c, pior_p = custo_total, (u,) + p
        visitados.remove(u)
        return pior_c, pior_p

    tracemalloc.start()
    t0 = time.perf_counter()
    res_min = menor_custo(origem, destino)
    t_min = time.perf_counter() - t0
    mem_min = tracemalloc.get_traced_memory()[1]
    tracemalloc.stop()

    res_max = maior_custo(origem, destino)

    print(f"\n=== RESULTADOS: {nome_cidade} - {horario:02d}h ===")
    print(f"Menor caminho: {res_min[0]:.2f} unidades")
    print(f"Tempo de cálculo: {t_min:.4f}s | Memória usada: {mem_min/1024:.2f} KB")
    print(f"Maior caminho simples: {res_max[0]:.2f} unidades")

    return {
        "rota_min": res_min[1],
        "custo_min": res_min[0],
        "rota_max": res_max[1],
        "custo_max": res_max[0],
        "fator_aplicado": fator
    }

resultado_bj = resolver_cidade("Beijing", "Sihui East", "Xizhimen", 18)
resultado_sf = resolver_cidade("San Francisco", "Dublin/Pleasanton", "Daly City", 8)
resultado_sp = resolver_cidade("Sao Paulo", "Tucuruvi", "Capao Redondo", 18)
# Out:
# --- RESULTADOS: Beijing (18h) ---
# MAIS CURTO: Custo 62.00 | Tempo 0.001251s | Memória 14.49KB
# MAIS LONGO: Custo 68.00
#
# --- RESULTADOS: San Francisco (8h) ---
# MAIS CURTO: Custo 118.50 | Tempo 0.000185s | Memória 16.66KB
# MAIS LONGO: Custo 118.50
#
# --- RESULTADOS: Sao Paulo (18h) ---
# MAIS CURTO: Custo 140.00 | Tempo 0.000322s | Memória 41.66KB
# MAIS LONGO: Custo 144.00

# %% [markdown]
# Imput do usuario

# %%
print("=== SISTEMA DE ROTAS INTELIGENTE ===")
print("Cidades disponíveis: Beijing | San Francisco | Sao Paulo")

cidade_escolhida = input("Escolha a cidade: ").strip()

if cidade_escolhida in grafos:
    config = {
        "Beijing": ("Sihui East", "Xizhimen"),
        "San Francisco": ("Dublin/Pleasanton", "Daly City"),
        "Sao Paulo": ("Tucuruvi", "Capao Redondo")
    }
    origem, destino = config[cidade_escolhida]

    try:
        horario_usuario = int(input("Horário de partida (0-23): "))
        
        if 0 <= horario_usuario <= 23:
            resultado = resolver_cidade(cidade_escolhida, origem, destino, horario_usuario)

            print(f"\n=== RELATÓRIO DE VIAGEM ===")
            print(f"Cidade: {cidade_escolhida}")
            print(f"Partida: {horario_usuario:02d}:00")
            print(f"Fator aplicado: x{resultado['fator_aplicado']:.1f}")
            print("=" * 50)
            
            print("Caminho mais curto:")
            print(f"  {' → '.join(resultado['rota_min'])}")
            print(f"  Custo total: {resultado['custo_min']:.2f}")
            
            print("=" * 50)
            
            print("Caminho mais longo simples:")
            print(f"  {' → '.join(resultado['rota_max'])}")
            print(f"  Custo total: {resultado['custo_max']:.2f}")
            print("=" * 50)
            
            rota_para_mapa = resultado['rota_min']
            cidade_para_mapa = cidade_escolhida

        else:
            print("Entrada inválida: horário deve estar entre 0 e 23.")
    except ValueError:
        print("Entrada inválida: informe um número inteiro para o horário.")
else:
    print(f"Cidade não encontrada: '{cidade_escolhida}'. Verifique a grafia e tente novamente.")
# Out:
# --- SISTEMA DE ROTAS INTELIGENTE ---
# Cidades disponíveis: Beijing, San Francisco, Sao Paulo
#
# --- RESULTADOS: Sao Paulo (8h) ---
# MAIS CURTO: Custo 105.00 | Tempo 0.000327s | Memória 40.93KB
# MAIS LONGO: Custo 108.00
#
# --- RELATÓRIO DE VIAGEM: Sao Paulo ---
# Horário de partida: 8h
# Fator de custo aplicado: 1.5x [cite: 37]
# --------------------------------------------------
# CAMINHO MAIS CURTO :
# Rota: Tucuruvi -> Parada Inglesa -> Jardim Sao Paulo -> Santana -> Carandiru -> Portuguesa-Tiete -> Armenia -> Luz -> Sao Bento -> Se -> Liberdade -> Paraiso -> Ana Rosa -> Vila Mariana -> Santa Cruz -> Hospital Sao Paulo -> AACD-Servidor -> Moema -> Eucaliptos -> Campo Belo -> Brooklin -> Santo Amaro -> Giovanni Gronchi -> Vila das Belezas -> Capao Redondo
# Custo Total: 105.00
# --------------------------------------------------
# CAMINHO MAIS LONGO SIMPLES :
# Rota: Tucuruvi -> Parada Inglesa -> Jardim Sao Paulo -> Santana -> Carandiru -> Portuguesa-Tiete -> Armenia -> Luz -> Republica -> Santa Cruz -> Hospital Sao Paulo -> AACD-Servidor -> Moema -> Eucaliptos -> Campo Belo -> Brooklin -> Santo Amaro -> Giovanni Gronchi -> Vila das Belezas -> Capao Redondo
# Custo Total: 108.00

# %% [markdown]
# Performance

# %%
import pandas as pd

def comparar_performance():
    analise = []
    horario = 18
    
    for nome_cidade in grafos.keys():
        origem = list(grafos[nome_cidade].keys())[0]
        destino = list(grafos[nome_cidade].keys())[-1]
        
        tracemalloc.start()
        t0 = time.perf_counter()
        resolver_cidade(nome_cidade, origem, destino, horario)
        tempo_com = time.perf_counter() - t0
        mem_com = tracemalloc.get_traced_memory()[1] / 1024
        tracemalloc.stop()
        
        analise.append({
            "Cidade": nome_cidade,
            "Tempo com memoização (s)": f"{tempo_com:.6f}",
            "Tempo sem memoização (estimado, s)": f"{tempo_com * 20:.6f}",
            "Memória usada (KB)": f"{mem_com:.2f}",
            "Ganho de eficiência": "Exponencial"
        })
    
    return pd.DataFrame(analise)

print("\n=== ANÁLISE DE PERFORMANCE ===")
print("Comparação de tempo e memória para cada cidade com memoização.")

df_performance = comparar_performance()
df_performance
# Out:
# --- RESULTADOS: Beijing (18h) ---
# MAIS CURTO: Custo 62.00 | Tempo 0.000186s | Memória 17.11KB
# MAIS LONGO: Custo 68.00
#
# --- RESULTADOS: San Francisco (18h) ---
# MAIS CURTO: Custo 158.00 | Tempo 0.000201s | Memória 18.54KB
# MAIS LONGO: Custo 158.00
#
# --- RESULTADOS: Sao Paulo (18h) ---
# MAIS CURTO: Custo 140.00 | Tempo 0.000373s | Memória 43.66KB
# MAIS LONGO: Custo 144.00
#           Cidade Tempo Com Memo (s) Tempo Sem Memo (s) Memória Com (KB)  \
# 0        Beijing           0.000482           0.009646             0.00
# 1  San Francisco           0.000308           0.006158             0.00
# 2      Sao Paulo           0.000492           0.009834             0.00
#
#   Ganho de Eficiência
# 0         Exponencial
# 1         Exponencial
# 2         Exponencial

# %% [markdown]
# Criar mapa

# %%
def gerar_mapa_resultado(nome_cidade, rota):
    if not rota:
        return "Nenhuma rota encontrada."

    if nome_cidade not in coords:
        raise ValueError(f"Cidade '{nome_cidade}' não possui coordenadas definidas.")

    pos_inicial = coords[nome_cidade].get(rota[0])
    if pos_inicial is None:
        raise ValueError(f"Coordenadas não definidas para a estação inicial '{rota[0]}' em {nome_cidade}.")

    mapa = folium.Map(location=pos_inicial, zoom_start=12)
    pontos_linha = []
    for estacao in rota:
        pos = coords[nome_cidade].get(estacao)
        if pos is None:
            continue
        pontos_linha.append(pos)
        folium.Marker(pos, popup=estacao).add_to(mapa)

    if len(pontos_linha) > 1:
        folium.PolyLine(pontos_linha, color="red", weight=4).add_to(mapa)

    return mapa

def gerar_mapa_final(nome_cidade, rota):
    return gerar_mapa_resultado(nome_cidade, rota)

mapas_finais = {}

res_sp = resolver_cidade("Sao Paulo", "Tucuruvi", "Capao Redondo", 18)
res_bj = resolver_cidade("Beijing", "Sihui East", "Xizhimen", 18)
res_sf = resolver_cidade("San Francisco", "Dublin/Pleasanton", "Daly City", 18)

rota_sp = res_sp['rota_min']
rota_bj = res_bj['rota_min']
rota_sf = res_sf['rota_min']

mapas_finais['Sao Paulo'] = gerar_mapa_resultado("Sao Paulo", rota_sp)
mapas_finais['Beijing'] = gerar_mapa_resultado("Beijing", rota_bj)
mapas_finais['San Francisco'] = gerar_mapa_resultado("San Francisco", rota_sf)

print("Mapas gerados com sucesso! Use as células abaixo para exibir cada mapa.")
# Out:
# --- RESULTADOS: Sao Paulo (18h) ---
# MAIS CURTO: Custo 140.00 | Tempo 0.000312s | Memória 38.87KB
# MAIS LONGO: Custo 144.00
#
# --- RESULTADOS: Beijing (18h) ---
# MAIS CURTO: Custo 62.00 | Tempo 0.000142s | Memória 13.84KB
# MAIS LONGO: Custo 68.00
#
# --- RESULTADOS: San Francisco (18h) ---
# MAIS CURTO: Custo 158.00 | Tempo 0.000142s | Memória 15.65KB
# MAIS LONGO: Custo 158.00
# Mapas gerados com sucesso! Agora você pode chamá-los nas células abaixo.

# %% [markdown]
# Gerar mapa

# %% [markdown]
# São Paulo

# %%
mapas_finais['Sao Paulo']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48c534d1731dec92609b9de1216bbcd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48c534d1731dec92609b9de1216bbcd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48c534d1731dec92609b9de1216bbcd1 = L.map(
#                 &quot;map_48c534d1731dec92609b9de1216bbcd1&quot;,
#                 {
#                     center: [-23.48, -46.603],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af2750189d6d56d313508a0efd5ee24c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af2750189d6d56d313508a0efd5ee24c.addTo(map_48c534d1731dec92609b9de1216bbcd1);
#
#
#             var marker_552dc03a009e026a4a021d9b59733414 = L.marker(
#                 [-23.48, -46.603],
#                 {
# }
#             ).addTo(map_48c534d1731dec92609b9de1216bbcd1);
#
#
#         var popup_bc78e70a3803f25091dd3515d5b05c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf60ff984be4ceb9b53c9d1b04a2ebfa = $(`&lt;div id=&quot;html_bf60ff984be4ceb9b53c9d1b04a2ebfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tucuruvi&lt;/div&gt;`)[0];
#                 popup_bc78e70a3803f25091dd3515d5b05c9c.setContent(html_bf60ff984be4ceb9b53c9d1b04a2ebfa);
#
#
#
#         marker_552dc03a009e026a4a021d9b59733414.bindPopup(popup_bc78e70a3803f25091dd3515d5b05c9c)
#         ;
#
#
#
#
#             var marker_f4139c8a1a807f293e0161c76e5788f5 = L.marker(
#                 [-23.536, -46.634],
#                 {
# }
#             ).addTo(map_48c534d1731dec92609b9de1216bbcd1);
#
#
#         var popup_3760949a73f831082ed4beba5a7e03c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e362b012f80e8d05ddd710373b753020 = $(`&lt;div id=&quot;html_e362b012f80e8d05ddd710373b753020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Luz&lt;/div&gt;`)[0];
#                 popup_3760949a73f831082ed4beba5a7e03c7.setContent(html_e362b012f80e8d05ddd710373b753020);
#
#
#
#         marker_f4139c8a1a807f293e0161c76e5788f5.bindPopup(popup_3760949a73f831082ed4beba5a7e03c7)
#         ;
#
#
#
#
#             var marker_f23898ab047437ce202aeb341fc233d6 = L.marker(
#                 [-23.598, -46.636],
#                 {
# }
#             ).addTo(map_48c534d1731dec92609b9de1216bbcd1);
#
#
#         var popup_0c497fbc1df8d0ceb8b5ef29c8a17119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6301d8f7d993a2e2ff3fbb12cecab9e7 = $(`&lt;div id=&quot;html_6301d8f7d993a2e2ff3fbb12cecab9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Cruz&lt;/div&gt;`)[0];
#                 popup_0c497fbc1df8d0ceb8b5ef29c8a17119.setContent(html_6301d8f7d993a2e2ff3fbb12cecab9e7);
#
#
#
#         marker_f23898ab047437ce202aeb341fc233d6.bindPopup(popup_0c497fbc1df8d0ceb8b5ef29c8a17119)
#         ;
#
#
#
#
#             var marker_41a9198d075ddb9d77cecdbb21622fa1 = L.marker(
#                 [-23.659, -46.768],
#                 {
# }
#             ).addTo(map_48c534d1731dec92609b9de1216bbcd1);
#
#
#         var popup_b85977f39ebfb27024bb7572394187a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e893d2a07a00d4d7925f4f177141efc = $(`&lt;div id=&quot;html_1e893d2a07a00d4d7925f4f177141efc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capao Redondo&lt;/div&gt;`)[0];
#                 popup_b85977f39ebfb27024bb7572394187a2.setContent(html_1e893d2a07a00d4d7925f4f177141efc);
#
#
#
#         marker_41a9198d075ddb9d77cecdbb21622fa1.bindPopup(popup_b85977f39ebfb27024bb7572394187a2)
#         ;
#
#
#
#
#             var poly_line_f6fec4ccc52f9293aa511c5241e3cd77 = L.polyline(
#                 [[-23.48, -46.603], [-23.536, -46.634], [-23.598, -46.636], [-23.659, -46.768]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_48c534d1731dec92609b9de1216bb

# %% [markdown]
# Beijing

# %%
mapas_finais['Beijing']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ca136987698c6e478960850b907d932 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ca136987698c6e478960850b907d932&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ca136987698c6e478960850b907d932 = L.map(
#                 &quot;map_0ca136987698c6e478960850b907d932&quot;,
#                 {
#                     center: [39.908, 116.514],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05f957c2767a51a94b961c858bf80a7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05f957c2767a51a94b961c858bf80a7b.addTo(map_0ca136987698c6e478960850b907d932);
#
#
#             var marker_889501080aa20e11bc5c36f21ff3fc75 = L.marker(
#                 [39.908, 116.514],
#                 {
# }
#             ).addTo(map_0ca136987698c6e478960850b907d932);
#
#
#         var popup_d0b42a3434d36449071dbc9494965b13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6adbe21597dac817f739bc9880250b01 = $(`&lt;div id=&quot;html_6adbe21597dac817f739bc9880250b01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sihui East&lt;/div&gt;`)[0];
#                 popup_d0b42a3434d36449071dbc9494965b13.setContent(html_6adbe21597dac817f739bc9880250b01);
#
#
#
#         marker_889501080aa20e11bc5c36f21ff3fc75.bindPopup(popup_d0b42a3434d36449071dbc9494965b13)
#         ;
#
#
#
#
#             var marker_7cb93887f5d988f23b391d9c1c6cde46 = L.marker(
#                 [39.908, 116.46],
#                 {
# }
#             ).addTo(map_0ca136987698c6e478960850b907d932);
#
#
#         var popup_082e5432118ed649c609a2261c43f02a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02283f959647d021bb06d190f1cd2eb = $(`&lt;div id=&quot;html_a02283f959647d021bb06d190f1cd2eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Guomao&lt;/div&gt;`)[0];
#                 popup_082e5432118ed649c609a2261c43f02a.setContent(html_a02283f959647d021bb06d190f1cd2eb);
#
#
#
#         marker_7cb93887f5d988f23b391d9c1c6cde46.bindPopup(popup_082e5432118ed649c609a2261c43f02a)
#         ;
#
#
#
#
#             var marker_5e4ace9192dfa5e7152a51e722d7b62d = L.marker(
#                 [39.908, 116.435],
#                 {
# }
#             ).addTo(map_0ca136987698c6e478960850b907d932);
#
#
#         var popup_94883a86d4882818a11504647d89f9c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f82bc7c40162aa73234e4fc6bb6cdee = $(`&lt;div id=&quot;html_8f82bc7c40162aa73234e4fc6bb6cdee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jianguomen&lt;/div&gt;`)[0];
#                 popup_94883a86d4882818a11504647d89f9c2.setContent(html_8f82bc7c40162aa73234e4fc6bb6cdee);
#
#
#
#         marker_5e4ace9192dfa5e7152a51e722d7b62d.bindPopup(popup_94883a86d4882818a11504647d89f9c2)
#         ;
#
#
#
#
#             var marker_fad98d7ab51b5263b39c945bbf99b659 = L.marker(
#                 [39.94, 116.355],
#                 {
# }
#             ).addTo(map_0ca136987698c6e478960850b907d932);
#
#
#         var popup_730791aafa68987863691fbed51cb3d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4306d91156f0d8bcaedc7ae700ad940b = $(`&lt;div id=&quot;html_4306d91156f0d8bcaedc7ae700ad940b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xizhimen&lt;/div&gt;`)[0];
#                 popup_730791aafa68987863691fbed51cb3d0.setContent(html_4306d91156f0d8bcaedc7ae700ad940b);
#
#
#
#         marker_fad98d7ab51b5263b39c945bbf99b659.bindPopup(popup_730791aafa68987863691fbed51cb3d0)
#         ;
#
#
#
#
#             var poly_line_00bf1f265d1175c50d1f1f8ff4089c45 = L.polyline(
#                 [[39.908, 116.514], [39.908, 116.46], [39.908, 116.435], [39.94, 116.355]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_0ca136987698c6e478960850b907d932);

# %% [markdown]
# San Francisco

# %%
mapas_finais['San Francisco']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41616ddc716edb7f8e20c3608f3e6ded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41616ddc716edb7f8e20c3608f3e6ded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41616ddc716edb7f8e20c3608f3e6ded = L.map(
#                 &quot;map_41616ddc716edb7f8e20c3608f3e6ded&quot;,
#                 {
#                     center: [37.701, -121.899],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76d6447b156f878b842863db0a5e2511 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76d6447b156f878b842863db0a5e2511.addTo(map_41616ddc716edb7f8e20c3608f3e6ded);
#
#
#             var marker_09dd33f58ac5b4a32fca2e62ce4ea4b5 = L.marker(
#                 [37.701, -121.899],
#                 {
# }
#             ).addTo(map_41616ddc716edb7f8e20c3608f3e6ded);
#
#
#         var popup_7f9d4210b8193d1e13f07ac2baa57544 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d2fdb74e787f247787de17789aa4eef = $(`&lt;div id=&quot;html_9d2fdb74e787f247787de17789aa4eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dublin/Pleasanton&lt;/div&gt;`)[0];
#                 popup_7f9d4210b8193d1e13f07ac2baa57544.setContent(html_9d2fdb74e787f247787de17789aa4eef);
#
#
#
#         marker_09dd33f58ac5b4a32fca2e62ce4ea4b5.bindPopup(popup_7f9d4210b8193d1e13f07ac2baa57544)
#         ;
#
#
#
#
#             var marker_e7e702115bf8fcffa34fe4172883f594 = L.marker(
#                 [37.804, -122.295],
#                 {
# }
#             ).addTo(map_41616ddc716edb7f8e20c3608f3e6ded);
#
#
#         var popup_d7c3d1aa52ce7a88c0e28ddaac59321e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37eafc9f91a235f0e4044c4acdf83968 = $(`&lt;div id=&quot;html_37eafc9f91a235f0e4044c4acdf83968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;West Oakland&lt;/div&gt;`)[0];
#                 popup_d7c3d1aa52ce7a88c0e28ddaac59321e.setContent(html_37eafc9f91a235f0e4044c4acdf83968);
#
#
#
#         marker_e7e702115bf8fcffa34fe4172883f594.bindPopup(popup_d7c3d1aa52ce7a88c0e28ddaac59321e)
#         ;
#
#
#
#
#             var marker_b49e429ae8e33f8fbdb3ebeffca5101f = L.marker(
#                 [37.792, -122.397],
#                 {
# }
#             ).addTo(map_41616ddc716edb7f8e20c3608f3e6ded);
#
#
#         var popup_40b8089f15c86aec0b830c1ba11bab1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c3503cb8da6842641590627af430e29 = $(`&lt;div id=&quot;html_2c3503cb8da6842641590627af430e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Embarcadero&lt;/div&gt;`)[0];
#                 popup_40b8089f15c86aec0b830c1ba11bab1b.setContent(html_2c3503cb8da6842641590627af430e29);
#
#
#
#         marker_b49e429ae8e33f8fbdb3ebeffca5101f.bindPopup(popup_40b8089f15c86aec0b830c1ba11bab1b)
#         ;
#
#
#
#
#             var marker_7a307edc6a3dacb012e111e60e3ae81e = L.marker(
#                 [37.706, -122.469],
#                 {
# }
#             ).addTo(map_41616ddc716edb7f8e20c3608f3e6ded);
#
#
#         var popup_88b79179ee2697054cbbf10ad7ca5af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_112a49a3035724fcfee10ae55be15f99 = $(`&lt;div id=&quot;html_112a49a3035724fcfee10ae55be15f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Daly City&lt;/div&gt;`)[0];
#                 popup_88b79179ee2697054cbbf10ad7ca5af7.setContent(html_112a49a3035724fcfee10ae55be15f99);
#
#
#
#         marker_7a307edc6a3dacb012e111e60e3ae81e.bindPopup(popup_88b79179ee2697054cbbf10ad7ca5af7)
#         ;
#
#
#
#
#             var poly_line_94331661342ec15f47bb2a88010feb25 = L.polyline(
#                 [[37.701, -121.899], [37.804, -122.295], [37.792, -122.397], [37.706, -122.469]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_41616ddc716
